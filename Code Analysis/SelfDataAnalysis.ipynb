# %% [markdown]
# # Self Data Analysis

# %% [markdown]
# Author: Patrick Smith
#
# Date: 18/03/2024
#
# Contact: patrick.b.smith@gmail.com

# %% [markdown]
# ## Objective
#
# Find out more about myself. Remembering the details

# %% [markdown]
# ## Table of Contents
#
# [Hockey](#Hockey)
#
# [Movies](#Movies)
#
# [Shows](#Shows)
#
# [Videogames](#VG)
#
# [Books](#Books)
#
# [Golf](#Golf)

# %%
## Data Loading

# %%
import pandas as pd
import os
import numpy as np
import matplotlib.pyplot as plt

# %%
# Full path to the Excel file
file_path = r'C:\Users\kamik\Downloads\20240525 - Data Science Personal Log.xlsx'

# Read the first sheet (default)
#df = pd.read_excel(file_path)

df_hockey = pd.read_excel(file_path, header=1, na_filter=False, sheet_name='Hockey')

# %%
df_hockey.head(15)
# Out:
#    Unnamed: 0           Unnamed: 1   Unnamed: 2   Unnamed: 3 Unnamed: 4  \
# 0                                                                   Est
# 1                             Date        Arena  Self-Rating      Goals
# 2                                                                     0
# 3              2024-06-11 00:00:00    McCormick          6.9          1
# 4              2024-06-25 00:00:00    McCormick          7.5          2
# 5              2024-07-02 00:00:00    McCormick          7.4          1
# 6              2024-07-09 00:00:00    McCormick          8.1          5
# 7              2024-07-16 00:00:00    McCormick          7.4          2
# 8              2024-07-23 00:00:00    McCormick          7.3          1
# 9              2024-07-30 00:00:00    McCormick          8.2          2
# 10             2024-07-31 00:00:00  Canlan York          8.1          1
# 11             2024-08-06 00:00:00    McCormick          8.4          5
# ...
